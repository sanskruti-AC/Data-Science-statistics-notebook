# %%
#exp no:3

# %%
#aim: Creating the Dataframe

# %%
# Name :- sanskruti ajay chandore
# Roll no : 09
# Sec : C
# Subject : ET1
# Date : 01/08/25

# %%
#creating series

# %%
import pandas as pd

# %%
name=["sana","vaish","tanu","gayu","prerna"]

# %%
name
# Out:
# ['sana', 'vaish', 'tanu', 'gayu', 'prerna']

# %%
roll_list=pd.Series(name,index=[1,2,3,4,5])
print(roll_list)
# Out:
# 1      sana
# 2     vaish
# 3      tanu
# 4      gayu
# 5    prerna
# dtype: object

# %%
#creating dataframe

# %%
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],columns=["DM","DSS","CAO","BIA"])

# %%
df
# Out:
#    DM  DSS  CAO  BIA
# 0  10   12   14   16
# 1  11   18   15   21
# 2  12   13   14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %%
#adding record (row)to the data frame

# %%
df2=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],columns=["DM","DSS","CAO","BIA"])

# %%
df3=pd.concat([df,df2],ignore_index=True)

# %%
df3
# Out:
#    DM  DSS  CAO  BIA
# 0  10   12   14   16
# 1  11   18   15   21
# 2  12   13   14   15
# 3  10   12   14   16
# 4  11   18   15   21
# 5  12   13   14   15

# %%
#deleting record from df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    DM  DSS  CAO  BIA
# 0  10   12   14   16
# 2  12   13   14   15
# 3  10   12   14   16
# 4  11   18   15   21
# 5  12   13   14   15

# %%
#adding attribute(colums)to data framne

# %%
df3["Dbms"]=[11,22,33,44,55,77]

# %%
df3
# Out:
#    DM  DSS  CAO  BIA  Dbms
# 0  10   12   14   16    11
# 1  11   18   15   21    22
# 2  12   13   14   15    33
# 3  10   12   14   16    44
# 4  11   18   15   21    55
# 5  12   13   14   15    77

# %%
#deleting attribute(columns)from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    DSS  CAO  BIA  Dbms
# 0   12   14   16    11
# 1   18   15   21    22
# 2   13   14   15    33
# 3   12   14   16    44
# 4   18   15   21    55
# 5   13   14   15    77

# %%
print("mean od DSS:",df5["DSS"].mean())
# Out:
# mean od DSS: 14.333333333333334

# %%
print("median of DSS:",df5["DSS"].median())
# Out:
# median of DSS: 13.0

# %%
print("mode of DSS:",df5["DSS"].mode())
# Out:
# mode of DSS: 0    12
# 1    13
# 2    18
# dtype: int64
