# %%
#Exp no: 2

# %%
#Aim :- To Perform operation of getting Basic statistical description of dataset

# %%
# Name :- sanskruti ajay chandore
# Roll no : 09
# Sec : C
# Subject : ET1
# Date : 01/08/25

# %%
age=[20,21,22,20,21 ,22,23,20,21,23,20,20,24,24,23,20,21]

# %%
age
# Out:
# [20, 21, 22, 20, 21, 22, 23, 20, 21, 23, 20, 20, 24, 24, 23, 20, 21]

# %%
print(age)
# Out:
# [20, 21, 22, 20, 21, 22, 23, 20, 21, 23, 20, 20, 24, 24, 23, 20, 21]

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a
# Out:
# 21.470588235294116

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21

# %%
c =statistics.mode(age)

# %%
c
# Out:
# 20

# %%
#performing cental tendancy of measure using numpy

# %%
import numpy as np
x= np.array([1,2,3,4,5,6,7,3,4,6,1,2,3,5,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 3, 4, 6, 1, 2, 3, 5, 6])

# %%
print(np.mean(x))
# Out:
# 3.8666666666666667

# %%
print(np.median(x))
# Out:
# 4.0

# %%
#performing cental tendancy of measures using scipy

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(3), count=np.int64(3))

# %%
print(np.std(x))
# Out:
# 1.8571184369578824

# %%
print(np.var(x))
# Out:
# 3.4488888888888884
