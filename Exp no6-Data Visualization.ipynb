# %%
#Exp no-6

# %%
#Aim: Data Visualization

# %%
#Name: Sanskruti ajay chandore
#Roll no.: 09
#Subject: ET1
#Sec: C
#Date: 19/08/2025

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.arange(1,9)

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
print(x)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
y=2*x

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16])

# %%
#Line Chart

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("Line Chart")
# Out:
# Text(0.5, 1.0, 'Line Chart')

# %%
plt.plot(x,y)
plt.title("Line Chart")
plt.xlabel("x axis")
# Out:
# Text(0.5, 0, 'x axis')

# %%
plt.plot(x,y)
plt.title("Line Chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
#Bar Chart

# %%
plt.bar(x,y)
plt.title("bar chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
random_number=np.random.rand()
print(random_number)
# Out:
# 0.3028388054651395

# %%
random_integer=np.random.randint(0,100)
print(random_integer)
# Out:
# 96

# %%
#Histogram

# %%
H=(1,2,2,3,3,3,4,2,5,5,5,5,6,77,76,65,65)

# %%
a=(1,2,3,5,7,9,8)
b=(12,44,56,77,78,90,11)
plt.scatter(a,b)
plt.title("scatter plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.hist(H)
plt.show()

# %%
#Boxplot

# %%
B=[1,2,3,4,5,6,7]

# %%
plt.boxplot(B)
plt.show()
